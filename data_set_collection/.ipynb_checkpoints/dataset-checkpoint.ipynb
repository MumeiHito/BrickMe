# %% [markdown]
# # Code to collect images of lego minifigures from https://www.bricklink.com/

# %% [markdown]
# ## 1. Getting list id's for all Lego themes

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import requests
from bs4 import BeautifulSoup
import re

HEADERS = {"User-Agent": "Mozilla/5.0"}
TREE_URL = "https://www.bricklink.com/catalogTree.asp?itemType=M"

def get_all_minifig_category_ids():
    resp = requests.get(TREE_URL, headers=HEADERS)
    soup = BeautifulSoup(resp.text, "html.parser")
    
    category_ids = set()

    for a in soup.find_all("a", href=True):
        match = re.search(r"catString=(\d+)", a['href'])
        if match:
            category_ids.add(match.group(1))

    return sorted(category_ids)

# %%
category_ids = get_all_minifig_category_ids()

# %%
print(f"Found {len(category_ids)} categories:")
print(category_ids)
# Out:
# Found 119 categories:
# ['102', '1042', '1043', '1069', '1070', '1095', '1100', '1125', '1154', '1163', '1166', '1197', '1203', '1221', '1227', '1236', '124', '1266', '1268', '1285', '1286', '1305', '1306', '1309', '1312', '153', '155', '157', '166', '167', '170', '174', '179', '227', '273', '277', '284', '294', '34', '36', '390', '447', '449', '469', '473', '48', '482', '490', '516', '53', '537', '54', '545', '548', '563', '568', '570', '572', '573', '574', '605', '608', '609', '61', '617', '62', '629', '65', '67', '689', '69', '732', '733', '734', '746', '747', '748', '749', '755', '757', '759', '761', '764', '768', '771', '78', '781', '787', '789', '790', '795', '801', '804', '807', '815', '817', '822', '842', '843', '85', '850', '856', '860', '868', '870', '876', '878', '893', '9', '918', '920', '925', '927', '957', '965', '971', '975', '976', '983']

# %% [markdown]
# ## 2. Now using id's to download all minifigures

# %%
import os
import re
import time
import requests
from bs4 import BeautifulSoup

HEADERS = {"User-Agent": "Mozilla/5.0"}
BASE_URL = "https://www.bricklink.com/catalogList.asp?catType=M&catString={}"
IMAGE_URL_TEMPLATE = "https://img.bricklink.com/ItemImage/MN/0/{}.png"
SAVE_DIR = "minifigs"

def get_minifig_ids_from_category_page(category_id):
    ids = []
    page = 1
    while True:
        paged_url = BASE_URL.format(category_id) + f"&pg={page}"
        print(paged_url)
        print(f"Parsing page {page} for category {category_id}...")
        resp = requests.get(paged_url, headers=HEADERS)
        soup = BeautifulSoup(resp.text, "html.parser")

        for a in soup.find_all("a", href=True):
            match = re.search(r"catalogitem\.page\?M=([\w\d]+)", a['href'])
            if match:
                minifig_id = match.group(1)
                if minifig_id not in ids:
                    ids.append(minifig_id)

        if not soup.find("a", text="Next"):
            break

        page += 1
        time.sleep(1)
    return ids

def download_minifig_images(minifig_ids, category_id):
    category_path = os.path.join(SAVE_DIR, category_id)
    os.makedirs(category_path, exist_ok=True)

    total = len(minifig_ids)
    print(f"Found {total} minifigs in category {category_id}.")

    for idx, fig_id in enumerate(minifig_ids, start=1):
        filepath = os.path.join(category_path, f"{fig_id}.png")
        if os.path.exists(filepath):
            print(f"Already exists: {fig_id} ({idx}/{total})")
            continue

        img_url = IMAGE_URL_TEMPLATE.format(fig_id)
        print(f"Downloading {fig_id}... {idx}/{total}")
        r = requests.get(img_url, headers=HEADERS)
        if r.status_code == 200:
            with open(filepath, "wb") as f:
                f.write(r.content)
        else:
            print(f"Image not found: {img_url}")

# %%
for cat_id in category_ids:
    minifig_ids = get_minifig_ids_from_category_page(cat_id)
    print(f"Found {len(minifig_ids)} minifigs in category {cat_id}.")
    download_minifig_images(minifig_ids, cat_id)
# Out:
# https://www.bricklink.com/catalogList.asp?catType=M&catString=102&pg=1
# Parsing page 1 for category 102...
# /var/folders/ll/yk8k24ls7ys7l35p4mx8q4100000gn/T/ipykernel_75349/2305530327.py:29: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   if not soup.find("a", text="Next"):
# Found 33 minifigs in category 102.
# Found 33 minifigs in category 102.
# Already exists: 71713 (1/33)
# Already exists: 71287 (2/33)
# Already exists: 72057 (3/33)
# Already exists: 72053 (4/33)
# Already exists: 23047c (5/33)
# Already exists: 71289b (6/33)
# Already exists: 23048 (7/33)
# Already exists: 72056 (8/33)
# Already exists: 23047b (9/33)
# Downloading 72058... 10/33
# Image not found: https://img.bricklink.com/ItemImage/MN/0/72058.png
# Already exists: 71520 (11/33)
# Already exists: 72055 (12/33)
# Already exists: 23049 (13/33)
# Already exists: 71289a (14/33)
# Already exists: 71518 (15/33)
# Already exists: 22447 (16/33)
# Already exists: 71519 (17/33)
# Already exists: 23047a (18/33)
# Already exists: x4cx02 (19/33)
# Already exists: x4cx01 (20/33)
# Already exists: scaFemA01 (21/33)
# Already exists: scaFemA02 (22/33)
# Already exists: scaFemA03 (23/33)
# Already exists: scaFemA04 (24/33)
# Already exists: scaFemA05 (25/33)
# Already exists: scaFemY01 (26/33)
# Already exists: scaFemY02 (27/33)
# Already exists: scaFemY03 (28/33)
# Already exists: scaFemY04 (29/33)
# Already exists: scaFemY06 (30/33)
# Already exists: scaFemY07 (31/33)
# Already exists: scaFemY05 (32/33)
# Already exists: x30 (33/33)
# https://www.bricklink.com/catalogList.asp?catType=M&catString=1042&pg=1
# Parsing page 1 for category 1042...
# https://www.bricklink.com/catalogList.asp?catType=M&catString=1042&pg=2
# Parsing page 2 for category 1042...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[73], line 2
#       1 for cat_id in category_ids:
# ----> 2     minifig_ids = get_minifig_ids_from_category_page(cat_id)
#       3     print(f"Found {len(minifig_ids)} minifigs in category {cat_id}.")
#       4     download_minifig_images(minifig_ids, cat_id)
#
# Cell In[2], line 20, in get_minifig_ids_from_category_page(category_id)
#      18 print(f"Parsing page {page} for category {category_id}...")
#      19 resp = requests.get(paged_url, headers=HEADERS)
# ---> 20 soup = BeautifulSoup(resp.text, "html.parser")
#      22 for a in soup.find_all("a", href=True):
#      23     match = re.search(r"catalogitem\.page\?M=([\w\d]+)", a['href'])
#
# File ~/anaconda3/envs/ml/lib/python3.10/site-packages/bs4/__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File ~/anaconda3/envs/ml/lib/python3.10/site-packages/bs4/__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File ~/anaconda3/envs/ml/lib/python3.10/site-packages/bs4/builder/_htmlparser.py:380, in HTMLParserTreeBuilder.feed(self, markup)
#     378 parser.soup = self.soup
#     379 try:
# --> 380     parser.feed(markup)
#     381     parser.close()
#     382 except AssertionError as e:
#     383     # html.parser raises AssertionError in rare cases to
#     384     # indicate a fatal problem with the markup, especially
#     385     # when there's an error in the doctype declaration.
#
# File ~/anaconda3/envs/ml/lib/python3.10/html/parser.py:110, in HTMLParser.feed(self, data)
#     104 r"""Feed data to the parser.
#     105
#     106 Call this as often as you want, with as little or as much text
#     107 as you want (may include '\n').
#     108 """
#     109 self.rawdata = self.rawdata + data
# --> 110 self.goahead(0)
#
# File ~/anaconda3/envs/ml/lib/python3.10/html/parser.py:165, in HTMLParser.goahead(self, end)
#     163     else:
#     164         self.handle_data(rawdata[i:j])
# --> 165 i = self.updatepos(i, j)
#     166 if i == n: break
#     167 startswith = rawdata.startswith
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3. Not all downloaded files are minifigures.
# first deleting all folders with non minifigure themes

# %% [markdown]
# 36 = Technic
# 48 = Belville
# 102 = Scala
# 153 = Fabuland
# 155 = Basic
# 167 = Duplo
# 273 = BIONICLE
# 277 = LEGOLAND
# 294 = Primo
# 490 = Clikits
# 516 = 4 Juniors
# 748 = Cars
# 749 = Hero factory
# 771 = Friends
# 801 = Minecraft
# 843 = Elves
# 876 = The Angry Birds Movie
# 893 = DC Super Hero Girls
# 965 = Unikitty!
# 1069 = Trolls World Tour
# 1070 = Despicable Me and Minions
# 1095 = Super Mario
# 1166 = Games
# 1266 = Gabby's Dollhouse
# 1285 = Animal Crossing
# 1305 = Wicked
# 1312 = Wednesday

# %% [markdown]
# using YOLO to detect torso on image. First labeling 500 random minifigures for torso detection

# %%
import os
import random
import shutil

minifigs_dir = "minifigs"
output_dir = "torsos"
os.makedirs(output_dir, exist_ok=True)

all_fig_paths = []
for root, dirs, files in os.walk(minifigs_dir):
    for file in files:
        if file.endswith(".png"):
            all_fig_paths.append(os.path.join(root, file))

sample_paths = random.sample(all_fig_paths, min(500, len(all_fig_paths)))

for src_path in sample_paths:
    filename = os.path.basename(src_path)
    dst_path = os.path.join(output_dir, filename)
    shutil.copy(src_path, dst_path)

print(f"✅ Copied {len(sample_paths)} images to {output_dir}")
# Out:
# ✅ Copied 500 images to torso2

# %% [markdown]
# # 4. training YOLOv5 for torso recognition

# %% [markdown]
# ## Installing YOLO

# %%
#!git clone https://github.com/ultralytics/yolov5

# %%
# !cd yolov5

# %%
pip install -r yolov5/requirements.txt
# Out:
# Collecting gitpython>=3.1.30 (from -r yolov5/requirements.txt (line 5))
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: matplotlib>=3.3 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 6)) (3.10.0)
# Requirement already satisfied: numpy>=1.23.5 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 7)) (1.26.4)
# Collecting opencv-python>=4.1.1 (from -r yolov5/requirements.txt (line 8))
#   Using cached opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=10.3.0 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 9)) (11.1.0)
# Requirement already satisfied: psutil in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 10)) (5.9.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 13)) (1.15.2)
# Collecting thop>=0.1.1 (from -r yolov5/requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.8.0 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 15)) (2.5.1)
# Collecting torchvision>=0.9.0 (from -r yolov5/requirements.txt (line 16))
#   Downloading torchvision-0.17.2-cp310-cp310-macosx_10_13_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 17)) (4.67.1)
# Collecting ultralytics>=8.2.34 (from -r yolov5/requirements.txt (line 18))
#   Downloading ultralytics-8.3.139-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: pandas>=1.1.4 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 27)) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: setuptools>=70.0.0 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from -r yolov5/requirements.txt (line 42)) (75.8.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->-r yolov5/requirements.txt (line 5))
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from requests>=2.32.2->-r yolov5/requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from requests>=2.32.2->-r yolov5/requirements.txt (line 12)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from requests>=2.32.2->-r yolov5/requirements.txt (line 12)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from requests>=2.32.2->-r yolov5/requirements.txt (line 12)) (2025.4.26)
# Requirement already satisfied: filelock in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (4.12.2)
# Requirement already satisfied: networkx in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.1.6)
# Requirement already satisfied: fsspec in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2024.12.0)
# Requirement already satisfied: sympy!=1.13.2,>=1.13.1 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (1.13.3)
# Collecting torch>=1.8.0 (from -r yolov5/requirements.txt (line 15))
#   Using cached torch-2.2.2-cp310-none-macosx_10_9_x86_64.whl.metadata (25 kB)
# Collecting py-cpuinfo (from ultralytics>=8.2.34->-r yolov5/requirements.txt (line 18))
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics>=8.2.34->-r yolov5/requirements.txt (line 18))
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: pytz>=2020.1 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27)) (2023.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r yolov5/requirements.txt (line 5))
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: six>=1.5 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/user/anaconda3/envs/ml/lib/python3.10/site-packages (from sympy!=1.13.2,>=1.13.1->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (1.3.0)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_x86_64.whl (56.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 MB 41.6 MB/s eta 0:00:0000:0100:01
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading torchvision-0.17.2-cp310-cp310-macosx_10_13_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 28.2 MB/s eta 0:00:00
# Using cached torch-2.2.2-cp310-none-macosx_10_9_x86_64.whl (150.8 MB)
# Downloading ultralytics-8.3.139-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 23.4 MB/s eta 0:00:00
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: py-cpuinfo, smmap, opencv-python, torch, gitdb, ultralytics-thop, torchvision, thop, gitpython, ultralytics
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1
#     Uninstalling torch-2.5.1:
#       Successfully uninstalled torch-2.5.1
# Successfully installed gitdb-4.0.12 gitpython-3.1.44 opencv-python-4.11.0.86 py-cpuinfo-9.0.0 smmap-5.0.2 thop-0.1.1.post2209072238 torch-2.2.2 torchvision-0.17.2 ultralytics-8.3.139 ultralytics-thop-2.0.14
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Getting files ready to train YOLOv5

# %%
import os

base = "lego-torso-yolo"
for split in ["train", "val"]:
    os.makedirs(os.path.join(base, "images", split), exist_ok=True)
    os.makedirs(os.path.join(base, "labels", split), exist_ok=True)

# %%
import os
import xml.etree.ElementTree as ET

IMG_DIR = "torsos"
LABEL_OUT_DIR = "yolo_labels"
os.makedirs(LABEL_OUT_DIR, exist_ok=True)

for file in os.listdir(IMG_DIR):
    if file.endswith(".xml"):
        tree = ET.parse(os.path.join(IMG_DIR, file))
        root = tree.getroot()
        size = root.find("size")
        w = int(size.find("width").text)
        h = int(size.find("height").text)

        output_lines = []
        for obj in root.findall("object"):
            if obj.find("name").text != "torso":
                continue

            bbox = obj.find("bndbox")
            xmin = int(bbox.find("xmin").text)
            xmax = int(bbox.find("xmax").text)
            ymin = int(bbox.find("ymin").text)
            ymax = int(bbox.find("ymax").text)

            x_center = ((xmin + xmax) / 2) / w
            y_center = ((ymin + ymax) / 2) / h
            width = (xmax - xmin) / w
            height = (ymax - ymin) / h

            output_lines.append(f"0 {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}")

        if output_lines:
            name = os.path.splitext(file)[0]
            with open(os.path.join(LABEL_OUT_DIR, name + ".txt"), "w") as f:
                f.write("\n".join(output_lines))

# %%
import os
import shutil
import random

img_dir = "torsos"
label_dir = "yolo_labels"
out_img = "lego-torso-yolo/images"
out_lbl = "lego-torso-yolo/labels"
os.makedirs(out_img + "/train", exist_ok=True)
os.makedirs(out_img + "/val", exist_ok=True)
os.makedirs(out_lbl + "/train", exist_ok=True)
os.makedirs(out_lbl + "/val", exist_ok=True)

all_files = [f for f in os.listdir(img_dir) if f.endswith(".png") and os.path.exists(os.path.join(label_dir, f.replace(".png", ".txt")))]
random.shuffle(all_files)
split = int(len(all_files) * 0.8)

for i, fname in enumerate(all_files):
    name = os.path.splitext(fname)[0]
    if i < split:
        part = "train"
    else:
        part = "val"
    shutil.copy(os.path.join(img_dir, fname), f"{out_img}/{part}/{fname}")
    shutil.copy(os.path.join(label_dir, name + ".txt"), f"{out_lbl}/{part}/{name}.txt")

# %%
data_yaml_content = """train: ../lego-torso-yolo/images/train
val: ../lego-torso-yolo/images/val

nc: 1
names: ['torso']
"""

output_path = "lego-torso-yolo/data.yaml"
with open(output_path, "w", encoding="utf-8") as f:
    f.write(data_yaml_content)

output_path
# Out:
# 'lego-torso-yolo/data.yaml'

# %% [markdown]
# ## Training YOLOv5 (in terminal)

# %% [markdown]
# python train.py --img 416 --batch 16 --epochs 50 --data ../lego-torso-yolo/data.yaml --weights yolov5s.pt --name lego_torso

# %%
python train.py --img 768 --batch 32 --epochs 100 --data ../lego-torso-yolo/data.yaml --weights yolov5s.pt --name lego_torso_768 --cache

# %%
#import torch
#print(torch.__version__)
#print("CUDA available:", torch.cuda.is_available())
#print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# 2.5.1+cu121
# CUDA available: True
# Device: NVIDIA GeForce RTX 4090

# %% [markdown]
# Weights are stored in yolov5\runs\train\lego_torso_768\weights\best.pt

# %% [markdown]
# Example of recognition

# %% [markdown]
# <img src="yolov5\runs\train\lego_torso_768\val_batch1_pred.jpg" width="400" height="200">

# %% [markdown]
# # 5. Using YOLOv5 to determine if there is a minifigure on a photo,
# ## then removing background with Rembg and splitting minifigure into head/torso/legs

# %%
#!pip install rembg

# %%
import torch
import numpy as np
import cv2
from PIL import Image
from rembg import remove
import io

# %%
test_img_minifig = 'minifigs\\34\\ac001.png' #minifigure
test_img_not_minifig =  'minifigs\\170\\alp007.png' #not minifigure

# %%
# loading model globally
yolo_model = torch.hub.load(
    'yolov5',
    'custom',
    path='yolov5\\runs\\train\\lego_torso_768\\weights\\best.pt',
    source='local'
)
def is_minifigure(img):
    if isinstance(img, str):
        img = Image.open(img).convert("RGB")
    results = yolo_model(img)
    detections = results.xyxy[0]  # x1, y1, x2, y2, conf, class
    return len(detections) > 0
# Out:
# YOLOv5  v7.0-418-ga493afe1 Python-3.12.9 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
def remove_background(img_path):
    with open(img_path, "rb") as f:
        input_image = f.read()
    output_image = remove(input_image)
    return Image.open(io.BytesIO(output_image)).convert("RGBA")
    
def remove_misc_only_largest(pil_img):
    img_rgba = np.array(pil_img)
    alpha = img_rgba[:, :, 3]

    # Бинаризуем альфа-канал
    mask = (alpha > 10).astype(np.uint8) * 255

    # Найти все связанные компоненты (контуры)
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(mask, connectivity=8)

    if num_labels <= 1:
        return pil_img

    # Находим компонент с наибольшей площадью (пропускаем label=0 — фон)
    largest_label = 1 + np.argmax(stats[1:, cv2.CC_STAT_AREA])

    # Создаём маску только для самой крупной области
    largest_mask = (labels == largest_label).astype(np.uint8) * 255

    # Применяем маску к изображению
    result_rgba = cv2.bitwise_and(img_rgba, img_rgba, mask=largest_mask)

    # Обнуляем пиксели вне области (делаем их прозрачными)
    result_rgba[largest_mask == 0] = [0, 0, 0, 0]

    return Image.fromarray(result_rgba)
        
def img_process(img_path):
    if not is_minifigure(img_path):
        print("not minifigure - skipping")
        return None
    print("processing")
    img_no_bg = remove_background(img_path)
    final = remove_misc_only_largest(img_no_bg)
    return final

# %%
test_path = 'minifigs\\34\\ac001.png'
test_path_misc = 'minifigs\\868\\nex004.png'
test_path_bg = 'minifigs\\9\\cas253.png'

# %%
img_process(test_path)
# Out:
# processing
# <PIL.Image.Image image mode=RGBA size=257x400>

# %%
img_process(test_path_bg)
# Out:
# processing
# <PIL.Image.Image image mode=RGBA size=240x320>

# %%
img_process(test_path_misc)
# Out:
# processing
# <PIL.Image.Image image mode=RGBA size=300x396>

# %% [markdown]
# ## Now we need to split minifigure into head/torso/legs

# %%
from PIL import ImageDraw

def draw_torso_box(pil_img):
    # getting predictions
    results = yolo_model(pil_img)
    detections = results.xyxy[0]

    if len(detections) == 0:
        return pil_img 

    # copy image for drawing
    img_with_box = pil_img.copy()
    draw = ImageDraw.Draw(img_with_box)

    for det in detections:
        x1, y1, x2, y2, conf, cls = det.tolist()
        draw.rectangle([x1, y1, x2, y2], outline="red", width=3)
        draw.text((x1, y1 - 10), f"torso {conf:.2f}", fill="red")

    return img_with_box

# %%
test = img_process(test_path)
# Out:
# processing

# %%
draw_torso_box(test)
# Out:
# <PIL.Image.Image image mode=RGBA size=257x400>

# %%
def split_minifigure(pil_img, name):
    results = yolo_model(pil_img)
    detections = results.xyxy[0]

    if len(detections) == 0:
        print("no torso - skipping")
        return
    best = detections[0]
    x1, y1, x2, y2 = map(int, best[:4])
    w, h = pil_img.size

    y1 = max(0, y1)
    y2 = min(h, y2)

    # cutting head / torso / legs
    head_region = pil_img.crop((0, 0, w, y1))
    torso_region = pil_img.crop((0, y1, w, y2))
    legs_region = pil_img.crop((0, y2, w, h))

    # saving
    head_region.save(f"head_{name}")
    torso_region.save(f"torso_{name}")
    legs_region.save(f"legs_{name}")

    print(f"✅ saved: head_{name}, torso_{name}, legs_{name}")

# %%
split_minifigure(test, 'test.png')
# Out:
# ✅ saved: head_test.png, torso_test.png, legs_test.png
# C:\Users\user\Desktop\GitHub\lego_project\data_set_collection\yolov5\models\common.py:907: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):

# %% [markdown]
# ## Making final function for img processing

# %%
import os
from PIL import Image

def img_process(img_path):
    # Extract the image name without extension
    name = os.path.splitext(os.path.basename(img_path))[0]

    if not is_minifigure(img_path):
        print(f"❌ [{name}] No torso detected — skipping")
        return "no_torso"

    print(f"✅ [{name}] Torso detected — processing...")

    # Step 1: Remove background
    img_no_bg = remove_background(img_path)

    # Step 2: Keep only the largest component (main figure)
    main_fig = remove_misc_only_largest(img_no_bg)

    # Step 3: Detect torso with YOLO
    results = yolo_model(main_fig)
    detections = results.xyxy[0]

    if len(detections) == 0:
        print(f"⚠️ [{name}] Torso not detected after cleanup — skipping")
        return

    # Step 4: Get bounding box of the detected torso
    x1, y1, x2, y2 = map(int, detections[0][:4])
    w, h = main_fig.size

    # Step 5: Split the image
    head_region = main_fig.crop((0, 0, w, y1))
    torso_region = main_fig.crop((0, y1, w, y2))
    legs_region = main_fig.crop((0, y2, w, h))

    # Step 6: Create output folders inside 'data_set'
    os.makedirs("data_set/head", exist_ok=True)
    os.makedirs("data_set/torso", exist_ok=True)
    os.makedirs("data_set/legs", exist_ok=True)

    # Step 7: Save the parts
    head_region.save(f"data_set/head/head_{name}.png")
    torso_region.save(f"data_set/torso/torso_{name}.png")
    legs_region.save(f"data_set/legs/legs_{name}.png")

    print(f"💾 [{name}] Saved to data_set")
    return "ok"

# %%
img_process(test_img_minifig)
# Out:
# ✅ [ac001] Torso detected — processing...
# 💾 [ac001] Saved to data_set
# 'ok'

# %% [markdown]
# # 6. Now prepairing data set for spliting minifigures into head/torso/legs

# %%
import os
import shutil
import time

def format_time(seconds):
    mins, secs = divmod(int(seconds), 60)
    return f"{mins}m {secs}s"

def process_all_minifigs(root_dir="minifigs"):
    # Step 1: gather all .png files
    all_files = []
    for subdir, _, files in os.walk(root_dir):
        for file in files:
            if file.lower().endswith(".png"):
                full_path = os.path.join(subdir, file)
                all_files.append(full_path)

    total = len(all_files)
    print(f"🔍 Found {total} images to process.")

    start_time = time.time()
    processed = 0

    # Step 2: processing loop
    for idx, path in enumerate(all_files, start=1):
        name = os.path.splitext(os.path.basename(path))[0]
        head_output = f"data_set/head/head_{name}.png"

        if os.path.exists(head_output):
            print(f"⏩ [{idx}/{total}] Skipped {name} — already processed")
            continue

        print(f"🔧 [{idx}/{total}] Processing: {name}", end="")

        t0 = time.time()
        try:
            result = img_process(path)
            if result == "no_torso":
                os.makedirs("ignored_minifigures", exist_ok=True)
                shutil.copy(path, os.path.join("ignored_minifigures", f"{name}.png"))
                print(" → saved to ignored_minifigures")
            else:
                print(" ✓ done")
        except Exception as e:
            print(f" ❌ failed — {e}")
            continue

        processed += 1
        elapsed = time.time() - start_time
        avg_time = elapsed / processed
        remaining = avg_time * (total - idx)

        print(f" ⏳ ETA: {format_time(remaining)}")

# %%
process_all_minifigs()
# Out:
# 🔍 Found 14120 images to process.
# ⏩ [1/14120] Skipped hs001 — already processed
# ⏩ [2/14120] Skipped hs002 — already processed
# ⏩ [3/14120] Skipped hs003 — already processed
# ⏩ [4/14120] Skipped hs004 — already processed
# ⏩ [5/14120] Skipped hs005 — already processed
# ⏩ [6/14120] Skipped hs006 — already processed
# ⏩ [7/14120] Skipped hs007 — already processed
# ⏩ [8/14120] Skipped hs008 — already processed
# ⏩ [9/14120] Skipped hs009 — already processed
# ⏩ [10/14120] Skipped hs010 — already processed
# ⏩ [11/14120] Skipped hs011 — already processed
# ⏩ [12/14120] Skipped hs012 — already processed
# ⏩ [13/14120] Skipped hs013 — already processed
# ⏩ [14/14120] Skipped hs014 — already processed
# ⏩ [15/14120] Skipped hs015 — already processed
# ⏩ [16/14120] Skipped hs016 — already processed
# ⏩ [17/14120] Skipped hs017 — already processed
# ⏩ [18/14120] Skipped hs018 — already processed
# ⏩ [19/14120] Skipped hs019 — already processed
# ⏩ [20/14120] Skipped hs020 — already processed
# ⏩ [21/14120] Skipped hs021 — already processed
# ⏩ [22/14120] Skipped hs022 — already processed
# ⏩ [23/14120] Skipped hs023 — already processed
# ⏩ [24/14120] Skipped hs024 — already processed
# ⏩ [25/14120] Skipped hs025 — already processed
# ⏩ [26/14120] Skipped hs026 — already processed
# ⏩ [27/14120] Skipped hs027 — already processed
# ⏩ [28/14120] Skipped hs028 — already processed
# ⏩ [29/14120] Skipped hs029 — already processed
# ⏩ [30/14120] Skipped hs030 — already processed
# ⏩ [31/14120] Skipped hs031 — already processed
# ⏩ [32/14120] Skipped hs032 — already processed
# ⏩ [33/14120] Skipped hs033 — already processed
# ⏩ [34/14120] Skipped hs034 — already processed
# ⏩ [35/14120] Skipped hs035 — already processed
# ⏩ [36/14120] Skipped hs036 — already processed
# ⏩ [37/14120] Skipped hs037 — already processed
# ⏩ [38/14120] Skipped hs038 — already processed
# ⏩ [39/14120] Skipped hs039 — already processed
# ⏩ [40/14120] Skipped hs040 — already processed
# ⏩ [41/14120] Skipped hs041 — already processed
# ⏩ [42/14120] Skipped hs042 — already processed
# ⏩ [43/14120] Skipped hs043 — already processed
# ⏩ [44/14120] Skipped hs044 — already processed
# ⏩ [45/14120] Skipped hs045 — already processed
# ⏩ [46/14120] Skipped hs046 — already processed
# ⏩ [47/14120] Skipped hs047 — already processed
# ⏩ [48/14120] Skipped hs048 — already processed
# ⏩ [49/14120] Skipped hs049 — already processed
# ⏩ [50/14120] Skipped hs050 — already processed
# ⏩ [51/14120] Skipped hs051 — already processed
# ⏩ [52/14120] Skipped hs052 — already processed
# ⏩ [53/14120] Skipped hs053 — already processed
# ⏩ [54/14120] Skipped hs054 — already processed
# ⏩ [55/14120] Skipped hs055 — already processed
# ⏩ [56/14120] Skipped hs056 — already processed
# ⏩ [57/14120] Skipped hs057 — already processed
# ⏩ [58/14120] Skipped hs058 — already processed
# ⏩ [59/14120] Skipped hs059 — already processed
# ⏩ [60/14120] Skipped hs060 — already processed
# ⏩ [61/14120] Skipped hs061 — already processed
# ⏩ [62/14120] Skipped hs062 — already processed
# ⏩ [63/14120] Skipped hs063 — already processed
# ⏩ [64/14120] Skipped hs064 — already processed
# ⏩ [65/14120] Skipped hs065 — already processed
# ⏩ [66/14120] Skipped hs066 — already processed
# ⏩ [67/14120] Skipped hs067 — already processed
# ⏩ [68/14120] Skipped hs068 — already processed
# ⏩ [69/14120] Skipped hs069 — already processed
# 🔧 [70/14120] Processing: hs070❌ [hs070] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 10m 38s
# ⏩ [71/14120] Skipped hs071 — already processed
# ⏩ [72/14120] Skipped hs072 — already processed
# 🔧 [73/14120] Processing: hs073❌ [hs073] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 8m 28s
# ⏩ [74/14120] Skipped hs074 — already processed
# ⏩ [75/14120] Skipped hs075 — already processed
# ⏩ [76/14120] Skipped st001 — already processed
# ⏩ [77/14120] Skipped st002 — already processed
# ⏩ [78/14120] Skipped st003 — already processed
# ⏩ [79/14120] Skipped st004 — already processed
# ⏩ [80/14120] Skipped st005 — already processed
# ⏩ [81/14120] Skipped st006 — already processed
# ⏩ [82/14120] Skipped st007 — already processed
# ⏩ [83/14120] Skipped st008 — already processed
# ⏩ [84/14120] Skipped st009 — already processed
# ⏩ [85/14120] Skipped mk001 — already processed
# ⏩ [86/14120] Skipped mk002 — already processed
# ⏩ [87/14120] Skipped mk003 — already processed
# 🔧 [88/14120] Processing: mk004❌ [mk004] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 7m 44s
# ⏩ [89/14120] Skipped mk005 — already processed
# ⏩ [90/14120] Skipped mk006 — already processed
# ⏩ [91/14120] Skipped mk007 — already processed
# ⏩ [92/14120] Skipped mk008 — already processed
# ⏩ [93/14120] Skipped mk009 — already processed
# ⏩ [94/14120] Skipped mk010 — already processed
# ⏩ [95/14120] Skipped mk011 — already processed
# ⏩ [96/14120] Skipped mk012 — already processed
# ⏩ [97/14120] Skipped mk013 — already processed
# ⏩ [98/14120] Skipped mk014 — already processed
# ⏩ [99/14120] Skipped mk015 — already processed
# ⏩ [100/14120] Skipped mk016 — already processed
# ⏩ [101/14120] Skipped mk017 — already processed
# ⏩ [102/14120] Skipped mk018 — already processed
# ⏩ [103/14120] Skipped mk019 — already processed
# ⏩ [104/14120] Skipped mk020 — already processed
# ⏩ [105/14120] Skipped mk021 — already processed
# ⏩ [106/14120] Skipped mk022 — already processed
# ⏩ [107/14120] Skipped mk023 — already processed
# ⏩ [108/14120] Skipped mk024 — already processed
# ⏩ [109/14120] Skipped mk025 — already processed
# ⏩ [110/14120] Skipped mk026 — already processed
# ⏩ [111/14120] Skipped mk026a — already processed
# ⏩ [112/14120] Skipped mk027 — already processed
# ⏩ [113/14120] Skipped mk028 — already processed
# ⏩ [114/14120] Skipped mk029 — already processed
# ⏩ [115/14120] Skipped mk030 — already processed
# ⏩ [116/14120] Skipped mk031 — already processed
# ⏩ [117/14120] Skipped mk032 — already processed
# ⏩ [118/14120] Skipped mk033 — already processed
# ⏩ [119/14120] Skipped mk034 — already processed
# ⏩ [120/14120] Skipped mk035 — already processed
# ⏩ [121/14120] Skipped mk036 — already processed
# ⏩ [122/14120] Skipped mk037 — already processed
# ⏩ [123/14120] Skipped mk038 — already processed
# ⏩ [124/14120] Skipped mk039 — already processed
# ⏩ [125/14120] Skipped mk040 — already processed
# ⏩ [126/14120] Skipped mk041 — already processed
# ⏩ [127/14120] Skipped mk042 — already processed
# ⏩ [128/14120] Skipped mk043 — already processed
# ⏩ [129/14120] Skipped mk044 — already processed
# ⏩ [130/14120] Skipped mk045 — already processed
# ⏩ [131/14120] Skipped mk046 — already processed
# ⏩ [132/14120] Skipped mk047 — already processed
# ⏩ [133/14120] Skipped mk048 — already processed
# ⏩ [134/14120] Skipped mk049 — already processed
# 🔧 [135/14120] Processing: mk050✅ [mk050] Torso detected — processing...
# ⚠️ [mk050] Torso not detected after cleanup — skipping
#  ✓ done
#  ⏳ ETA: 44m 44s
# 🔧 [136/14120] Processing: mk051✅ [mk051] Torso detected — processing...
# ⚠️ [mk051] Torso not detected after cleanup — skipping
#  ✓ done
#  ⏳ ETA: 63m 41s
# ⏩ [137/14120] Skipped mk052 — already processed
# ⏩ [138/14120] Skipped mk053 — already processed
# ⏩ [139/14120] Skipped mk054 — already processed
# ⏩ [140/14120] Skipped mk055 — already processed
# ⏩ [141/14120] Skipped mk056 — already processed
# ⏩ [142/14120] Skipped mk057 — already processed
# ⏩ [143/14120] Skipped mk058 — already processed
# ⏩ [144/14120] Skipped mk059 — already processed
# ⏩ [145/14120] Skipped mk060 — already processed
# ⏩ [146/14120] Skipped mk061 — already processed
# ⏩ [147/14120] Skipped mk062 — already processed
# ⏩ [148/14120] Skipped mk063 — already processed
# ⏩ [149/14120] Skipped mk064 — already processed
# ⏩ [150/14120] Skipped mk065 — already processed
# ⏩ [151/14120] Skipped mk066 — already processed
# ⏩ [152/14120] Skipped mk067 — already processed
# 🔧 [153/14120] Processing: mk068❌ [mk068] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 53m 14s
# 🔧 [154/14120] Processing: mk069❌ [mk069] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 45m 48s
# ⏩ [155/14120] Skipped mk070 — already processed
# ⏩ [156/14120] Skipped mk071 — already processed
# ⏩ [157/14120] Skipped mk072 — already processed
# ⏩ [158/14120] Skipped mk073 — already processed
# ⏩ [159/14120] Skipped mk074 — already processed
# ⏩ [160/14120] Skipped mk075 — already processed
# ⏩ [161/14120] Skipped mk076 — already processed
# ⏩ [162/14120] Skipped mk077 — already processed
# ⏩ [163/14120] Skipped mk078 — already processed
# ⏩ [164/14120] Skipped mk079 — already processed
# ⏩ [165/14120] Skipped mk080 — already processed
# ⏩ [166/14120] Skipped mk081 — already processed
# ⏩ [167/14120] Skipped mk082 — already processed
# ⏩ [168/14120] Skipped mk083 — already processed
# ⏩ [169/14120] Skipped mk084 — already processed
# ⏩ [170/14120] Skipped mk085 — already processed
# ⏩ [171/14120] Skipped mk086 — already processed
# ⏩ [172/14120] Skipped mk087 — already processed
# ⏩ [173/14120] Skipped mk088 — already processed
# ⏩ [174/14120] Skipped mk089 — already processed
# ⏩ [175/14120] Skipped mk090 — already processed
# ⏩ [176/14120] Skipped mk091 — already processed
# ⏩ [177/14120] Skipped mk092 — already processed
# 🔧 [178/14120] Processing: mk093❌ [mk093] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 40m 38s
# ⏩ [179/14120] Skipped mk094 — already processed
# ⏩ [180/14120] Skipped mk095 — already processed
# ⏩ [181/14120] Skipped mk096 — already processed
# ⏩ [182/14120] Skipped mk097 — already processed
# ⏩ [183/14120] Skipped mk098 — already processed
# ⏩ [184/14120] Skipped mk099 — already processed
# ⏩ [185/14120] Skipped mk100 — already processed
# ⏩ [186/14120] Skipped mk101 — already processed
# ⏩ [187/14120] Skipped mk102 — already processed
# ⏩ [188/14120] Skipped mk103 — already processed
# ⏩ [189/14120] Skipped mk104 — already processed
# ⏩ [190/14120] Skipped mk105 — already processed
# ⏩ [191/14120] Skipped mk106 — already processed
# ⏩ [192/14120] Skipped mk107 — already processed
# ⏩ [193/14120] Skipped mk108 — already processed
# ⏩ [194/14120] Skipped mk109 — already processed
# ⏩ [195/14120] Skipped mk110 — already processed
# ⏩ [196/14120] Skipped mk111 — already processed
# ⏩ [197/14120] Skipped mk112 — already processed
# ⏩ [198/14120] Skipped mk113 — already processed
# ⏩ [199/14120] Skipped mk114 — already processed
# ⏩ [200/14120] Skipped mk115 — already processed
# ⏩ [201/14120] Skipped mk116 — already processed
# ⏩ [202/14120] Skipped mk117 — already processed
# ⏩ [203/14120] Skipped mk118 — already processed
# ⏩ [204/14120] Skipped mk119 — already processed
# ⏩ [205/14120] Skipped mk120 — already processed
# ⏩ [206/14120] Skipped mk121 — already processed
# ⏩ [207/14120] Skipped mk122 — already processed
# ⏩ [208/14120] Skipped mk123 — already processed
# ⏩ [209/14120] Skipped mk124 — already processed
# ⏩ [210/14120] Skipped mk125 — already processed
# ⏩ [211/14120] Skipped mk126 — already processed
# ⏩ [212/14120] Skipped mk127 — already processed
# ⏩ [213/14120] Skipped mk128 — already processed
# ⏩ [214/14120] Skipped mk129 — already processed
# ⏩ [215/14120] Skipped mk130 — already processed
# ⏩ [216/14120] Skipped mk131 — already processed
# ⏩ [217/14120] Skipped mk132 — already processed
# ⏩ [218/14120] Skipped mk133 — already processed
# ⏩ [219/14120] Skipped mk134 — already processed
# ⏩ [220/14120] Skipped mk135 — already processed
# ⏩ [221/14120] Skipped mk136 — already processed
# 🔧 [222/14120] Processing: mk137s❌ [mk137s] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 36m 33s
# ⏩ [223/14120] Skipped mk138 — already processed
# ⏩ [224/14120] Skipped mk139 — already processed
# ⏩ [225/14120] Skipped mk140 — already processed
# ⏩ [226/14120] Skipped mk141 — already processed
# ⏩ [227/14120] Skipped mk142 — already processed
# ⏩ [228/14120] Skipped mk143 — already processed
# ⏩ [229/14120] Skipped mk144 — already processed
# ⏩ [230/14120] Skipped mk145 — already processed
# ⏩ [231/14120] Skipped mk146 — already processed
# ⏩ [232/14120] Skipped mk147 — already processed
# ⏩ [233/14120] Skipped mk148 — already processed
# ⏩ [234/14120] Skipped mk149 — already processed
# ⏩ [235/14120] Skipped mk150 — already processed
# ⏩ [236/14120] Skipped mk151 — already processed
# ⏩ [237/14120] Skipped mk152 — already processed
# ⏩ [238/14120] Skipped mk153 — already processed
# 🔧 [239/14120] Processing: mk154❌ [mk154] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 32m 59s
# 🔧 [240/14120] Processing: mk155❌ [mk155] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 30m 25s
# 🔧 [241/14120] Processing: mk156✅ [mk156] Torso detected — processing...
# ⚠️ [mk156] Torso not detected after cleanup — skipping
#  ✓ done
#  ⏳ ETA: 35m 50s
# ⏩ [242/14120] Skipped mk157 — already processed
# ⏩ [243/14120] Skipped mk158 — already processed
# ⏩ [244/14120] Skipped mk159 — already processed
# ⏩ [245/14120] Skipped mk160 — already processed
# ⏩ [246/14120] Skipped mk161 — already processed
# ⏩ [247/14120] Skipped mk162 — already processed
# ⏩ [248/14120] Skipped mk163 — already processed
# ⏩ [249/14120] Skipped mk164 — already processed
# ⏩ [250/14120] Skipped mk165 — already processed
# ⏩ [251/14120] Skipped mk166 — already processed
# ⏩ [252/14120] Skipped mk167 — already processed
# ⏩ [253/14120] Skipped mk168 — already processed
# ⏩ [254/14120] Skipped mk169 — already processed
# ⏩ [255/14120] Skipped mk170 — already processed
# ⏩ [256/14120] Skipped mk171 — already processed
# ⏩ [257/14120] Skipped mk172 — already processed
# ⏩ [258/14120] Skipped mk173 — already processed
# ⏩ [259/14120] Skipped mk174 — already processed
# ⏩ [260/14120] Skipped mk175 — already processed
# ⏩ [261/14120] Skipped mk176 — already processed
# ⏩ [262/14120] Skipped mk177 — already processed
# ⏩ [263/14120] Skipped mk178 — already processed
# ⏩ [264/14120] Skipped mk179 — already processed
# ⏩ [265/14120] Skipped mk180 — already processed
# ⏩ [266/14120] Skipped mk181 — already processed
# ⏩ [267/14120] Skipped mk182 — already processed
# ⏩ [268/14120] Skipped vid001 — already processed
# ⏩ [269/14120] Skipped vid002 — already processed
# ⏩ [270/14120] Skipped vid003 — already processed
# ⏩ [271/14120] Skipped vid004 — already processed
# ⏩ [272/14120] Skipped vid004a — already processed
# ⏩ [273/14120] Skipped vid005 — already processed
# ⏩ [274/14120] Skipped vid006 — already processed
# ⏩ [275/14120] Skipped vid007 — already processed
# ⏩ [276/14120] Skipped vid008 — already processed
# ⏩ [277/14120] Skipped vid009 — already processed
# ⏩ [278/14120] Skipped vid010 — already processed
# ⏩ [279/14120] Skipped vid011 — already processed
# ⏩ [280/14120] Skipped vid012 — already processed
# ⏩ [281/14120] Skipped vid013 — already processed
# ⏩ [282/14120] Skipped vid014 — already processed
# ⏩ [283/14120] Skipped vid015 — already processed
# ⏩ [284/14120] Skipped vid016 — already processed
# ⏩ [285/14120] Skipped vid017 — already processed
# ⏩ [286/14120] Skipped vid018 — already processed
# ⏩ [287/14120] Skipped vid019 — already processed
# ⏩ [288/14120] Skipped vid020 — already processed
# ⏩ [289/14120] Skipped vid021 — already processed
# ⏩ [290/14120] Skipped vid022 — already processed
# ⏩ [291/14120] Skipped vid023 — already processed
# ⏩ [292/14120] Skipped vid024 — already processed
# ⏩ [293/14120] Skipped vid025 — already processed
# ⏩ [294/14120] Skipped vid026 — already processed
# ⏩ [295/14120] Skipped vid027 — already processed
# ⏩ [296/14120] Skipped vid028 — already processed
# ⏩ [297/14120] Skipped vid029 — already processed
# ⏩ [298/14120] Skipped vid030 — already processed
# ⏩ [299/14120] Skipped vid031 — already processed
# ⏩ [300/14120] Skipped vid032 — already processed
# ⏩ [301/14120] Skipped vid033 — already processed
# ⏩ [302/14120] Skipped vid034 — already processed
# ⏩ [303/14120] Skipped vid035 — already processed
# ⏩ [304/14120] Skipped vid036 — already processed
# ⏩ [305/14120] Skipped vid037 — already processed
# ⏩ [306/14120] Skipped vid038 — already processed
# ⏩ [307/14120] Skipped vid039 — already processed
# ⏩ [308/14120] Skipped vid040 — already processed
# ⏩ [309/14120] Skipped vid041 — already processed
# ⏩ [310/14120] Skipped vid042 — already processed
# ⏩ [311/14120] Skipped vid043 — already processed
# ⏩ [312/14120] Skipped vid044 — already processed
# ⏩ [313/14120] Skipped vid045 — already processed
# ⏩ [314/14120] Skipped vid046 — already processed
# ⏩ [315/14120] Skipped ftv001 — already processed
# ⏩ [316/14120] Skipped ftv002 — already processed
# ⏩ [317/14120] Skipped ftv003 — already processed
# ⏩ [318/14120] Skipped ftv004 — already processed
# ⏩ [319/14120] Skipped ftv005 — already processed
# ⏩ [320/14120] Skipped ftv006 — already processed
# ⏩ [321/14120] Skipped ftv007 — already processed
# ⏩ [322/14120] Skipped que001 — already processed
# ⏩ [323/14120] Skipped que002 — already processed
# ⏩ [324/14120] Skipped que003 — already processed
# ⏩ [325/14120] Skipped que004 — already processed
# ⏩ [326/14120] Skipped que005 — already processed
# ⏩ [327/14120] Skipped que006 — already processed
# ⏩ [328/14120] Skipped que007 — already processed
# ⏩ [329/14120] Skipped adp001 — already processed
# ⏩ [330/14120] Skipped adp002 — already processed
# ⏩ [331/14120] Skipped adp003 — already processed
# ⏩ [332/14120] Skipped adp004 — already processed
# ⏩ [333/14120] Skipped adp005 — already processed
# ⏩ [334/14120] Skipped adp006 — already processed
# ⏩ [335/14120] Skipped adp007 — already processed
# ⏩ [336/14120] Skipped adp008 — already processed
# ⏩ [337/14120] Skipped adp009 — already processed
# ⏩ [338/14120] Skipped adp010 — already processed
# ⏩ [339/14120] Skipped adp011 — already processed
# ⏩ [340/14120] Skipped adp012 — already processed
# ⏩ [341/14120] Skipped adp013 — already processed
# ⏩ [342/14120] Skipped adp014 — already processed
# ⏩ [343/14120] Skipped adp015 — already processed
# ⏩ [344/14120] Skipped adp016 — already processed
# ⏩ [345/14120] Skipped adp017 — already processed
# ⏩ [346/14120] Skipped adp018 — already processed
# ⏩ [347/14120] Skipped adp019 — already processed
# ⏩ [348/14120] Skipped adp020 — already processed
# ⏩ [349/14120] Skipped adp021 — already processed
# ⏩ [350/14120] Skipped adp022 — already processed
# ⏩ [351/14120] Skipped adp023 — already processed
# ⏩ [352/14120] Skipped adp024 — already processed
# ⏩ [353/14120] Skipped adp025 — already processed
# ⏩ [354/14120] Skipped adp026 — already processed
# ⏩ [355/14120] Skipped adp027 — already processed
# ⏩ [356/14120] Skipped adp028 — already processed
# ⏩ [357/14120] Skipped adp029 — already processed
# ⏩ [358/14120] Skipped adp030 — already processed
# ⏩ [359/14120] Skipped adp031 — already processed
# ⏩ [360/14120] Skipped adp032 — already processed
# ⏩ [361/14120] Skipped adp033 — already processed
# ⏩ [362/14120] Skipped adp034 — already processed
# ⏩ [363/14120] Skipped adp035 — already processed
# ⏩ [364/14120] Skipped adp036 — already processed
# ⏩ [365/14120] Skipped adp037 — already processed
# ⏩ [366/14120] Skipped adp038 — already processed
# ⏩ [367/14120] Skipped adp039 — already processed
# ⏩ [368/14120] Skipped adp040 — already processed
# ⏩ [369/14120] Skipped adp041 — already processed
# ⏩ [370/14120] Skipped adp042 — already processed
# ⏩ [371/14120] Skipped adp043 — already processed
# ⏩ [372/14120] Skipped adp044 — already processed
# ⏩ [373/14120] Skipped adp045 — already processed
# ⏩ [374/14120] Skipped adp046 — already processed
# ⏩ [375/14120] Skipped adp047 — already processed
# ⏩ [376/14120] Skipped adp048 — already processed
# 🔧 [377/14120] Processing: adp049❌ [adp049] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 32m 55s
# ⏩ [378/14120] Skipped adp050 — already processed
# ⏩ [379/14120] Skipped adp051 — already processed
# ⏩ [380/14120] Skipped adp052 — already processed
# ⏩ [381/14120] Skipped adp053 — already processed
# ⏩ [382/14120] Skipped adp054 — already processed
# ⏩ [383/14120] Skipped adp055 — already processed
# ⏩ [384/14120] Skipped adp056 — already processed
# ⏩ [385/14120] Skipped adp057 — already processed
# ⏩ [386/14120] Skipped adp058 — already processed
# ⏩ [387/14120] Skipped adp059 — already processed
# ⏩ [388/14120] Skipped adp060 — already processed
# ⏩ [389/14120] Skipped adp061 — already processed
# ⏩ [390/14120] Skipped adp062 — already processed
# ⏩ [391/14120] Skipped adp063 — already processed
# ⏩ [392/14120] Skipped adp064 — already processed
# ⏩ [393/14120] Skipped adp065 — already processed
# ⏩ [394/14120] Skipped adp066 — already processed
# ⏩ [395/14120] Skipped adp067 — already processed
# ⏩ [396/14120] Skipped adp068 — already processed
# ⏩ [397/14120] Skipped adp069 — already processed
# ⏩ [398/14120] Skipped adp070 — already processed
# ⏩ [399/14120] Skipped adp071 — already processed
# ⏩ [400/14120] Skipped adp072 — already processed
# ⏩ [401/14120] Skipped adp073 — already processed
# ⏩ [402/14120] Skipped adp074 — already processed
# ⏩ [403/14120] Skipped adp075 — already processed
# ⏩ [404/14120] Skipped adp076 — already processed
# ⏩ [405/14120] Skipped adp077 — already processed
# ⏩ [406/14120] Skipped adp078 — already processed
# ⏩ [407/14120] Skipped adp079 — already processed
# ⏩ [408/14120] Skipped adp080 — already processed
# ⏩ [409/14120] Skipped adp081 — already processed
# ⏩ [410/14120] Skipped adp082 — already processed
# ⏩ [411/14120] Skipped adp083 — already processed
# ⏩ [412/14120] Skipped adp084 — already processed
# ⏩ [413/14120] Skipped adp085 — already processed
# ⏩ [414/14120] Skipped adp086 — already processed
# ⏩ [415/14120] Skipped adp087 — already processed
# ⏩ [416/14120] Skipped adp088 — already processed
# ⏩ [417/14120] Skipped adp089 — already processed
# ⏩ [418/14120] Skipped adp090 — already processed
# ⏩ [419/14120] Skipped adp091 — already processed
# ⏩ [420/14120] Skipped adp092 — already processed
# ⏩ [421/14120] Skipped adp093 — already processed
# ⏩ [422/14120] Skipped adp094 — already processed
# ⏩ [423/14120] Skipped adp095 — already processed
# ⏩ [424/14120] Skipped adp096 — already processed
# ⏩ [425/14120] Skipped adp097 — already processed
# ⏩ [426/14120] Skipped adp098 — already processed
# ⏩ [427/14120] Skipped adp099 — already processed
# ⏩ [428/14120] Skipped adp100 — already processed
# ⏩ [429/14120] Skipped adp101 — already processed
# ⏩ [430/14120] Skipped adp102 — already processed
# ⏩ [431/14120] Skipped adp103 — already processed
# ⏩ [432/14120] Skipped adp104 — already processed
# ⏩ [433/14120] Skipped adp105 — already processed
# ⏩ [434/14120] Skipped adp106 — already processed
# ⏩ [435/14120] Skipped adp107 — already processed
# ⏩ [436/14120] Skipped adp108 — already processed
# ⏩ [437/14120] Skipped adp109 — already processed
# ⏩ [438/14120] Skipped adp110 — already processed
# ⏩ [439/14120] Skipped adp111 — already processed
# ⏩ [440/14120] Skipped adp112 — already processed
# ⏩ [441/14120] Skipped adp113 — already processed
# ⏩ [442/14120] Skipped adp114 — already processed
# ⏩ [443/14120] Skipped adp115 — already processed
# ⏩ [444/14120] Skipped adp116 — already processed
# ⏩ [445/14120] Skipped adp117 — already processed
# ⏩ [446/14120] Skipped adp118 — already processed
# ⏩ [447/14120] Skipped adp119 — already processed
# ⏩ [448/14120] Skipped adp120 — already processed
# ⏩ [449/14120] Skipped adp121 — already processed
# ⏩ [450/14120] Skipped adp122 — already processed
# ⏩ [451/14120] Skipped adp123 — already processed
# ⏩ [452/14120] Skipped adp124 — already processed
# ⏩ [453/14120] Skipped adp125 — already processed
# ⏩ [454/14120] Skipped adp126 — already processed
# ⏩ [455/14120] Skipped adp127 — already processed
# ⏩ [456/14120] Skipped adp128 — already processed
# ⏩ [457/14120] Skipped adp129 — already processed
# ⏩ [458/14120] Skipped adp130 — already processed
# ⏩ [459/14120] Skipped adp131 — already processed
# ⏩ [460/14120] Skipped adp132 — already processed
# ⏩ [461/14120] Skipped adp133 — already processed
# ⏩ [462/14120] Skipped adp134 — already processed
# ⏩ [463/14120] Skipped adp135 — already processed
# ⏩ [464/14120] Skipped adp136 — already processed
# ⏩ [465/14120] Skipped adp137 — already processed
# ⏩ [466/14120] Skipped adp138 — already processed
# ⏩ [467/14120] Skipped adp139 — already processed
# ⏩ [468/14120] Skipped adp140 — already processed
# ⏩ [469/14120] Skipped adp141 — already processed
# ⏩ [470/14120] Skipped adp142 — already processed
# ⏩ [471/14120] Skipped adp143 — already processed
# ⏩ [472/14120] Skipped adp144 — already processed
# ⏩ [473/14120] Skipped adp145 — already processed
# ⏩ [474/14120] Skipped adp146 — already processed
# ⏩ [475/14120] Skipped adp147 — already processed
# ⏩ [476/14120] Skipped adp148 — already processed
# ⏩ [477/14120] Skipped adp149 — already processed
# ⏩ [478/14120] Skipped adp150 — already processed
# ⏩ [479/14120] Skipped adp151 — already processed
# ⏩ [480/14120] Skipped adp152 — already processed
# ⏩ [481/14120] Skipped adp153 — already processed
# ⏩ [482/14120] Skipped adp154 — already processed
# ⏩ [483/14120] Skipped adp155 — already processed
# ⏩ [484/14120] Skipped adp156 — already processed
# ⏩ [485/14120] Skipped adp157 — already processed
# ⏩ [486/14120] Skipped adp158 — already processed
# ⏩ [487/14120] Skipped adp159 — already processed
# ⏩ [488/14120] Skipped adp160 — already processed
# ⏩ [489/14120] Skipped adp161 — already processed
# ⏩ [490/14120] Skipped adp162 — already processed
# ⏩ [491/14120] Skipped adp163 — already processed
# ⏩ [492/14120] Skipped adp164 — already processed
# ⏩ [493/14120] Skipped adp165 — already processed
# ⏩ [494/14120] Skipped adp166 — already processed
# ⏩ [495/14120] Skipped adp167 — already processed
# ⏩ [496/14120] Skipped adp168 — already processed
# 🔧 [497/14120] Processing: adp169✅ [adp169] Torso detected — processing...
# ⚠️ [adp169] Torso not detected after cleanup — skipping
#  ✓ done
#  ⏳ ETA: 37m 4s
# ⏩ [498/14120] Skipped adp170 — already processed
# ⏩ [499/14120] Skipped adp171 — already processed
# ⏩ [500/14120] Skipped adp172 — already processed
# ⏩ [501/14120] Skipped adp173 — already processed
# ⏩ [502/14120] Skipped adp174 — already processed
# ⏩ [503/14120] Skipped adp175 — already processed
# ⏩ [504/14120] Skipped adp176 — already processed
# ⏩ [505/14120] Skipped adp177 — already processed
# ⏩ [506/14120] Skipped son001 — already processed
# ⏩ [507/14120] Skipped son002 — already processed
# ⏩ [508/14120] Skipped son003 — already processed
# ⏩ [509/14120] Skipped son004 — already processed
# ⏩ [510/14120] Skipped son005 — already processed
# 🔧 [511/14120] Processing: son006❌ [son006] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 34m 53s
# 🔧 [512/14120] Processing: son007❌ [son007] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 32m 46s
# ⏩ [513/14120] Skipped son008 — already processed
# 🔧 [514/14120] Processing: son009❌ [son009] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 31m 8s
# 🔧 [515/14120] Processing: son010❌ [son010] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 29m 28s
# 🔧 [516/14120] Processing: son011❌ [son011] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 28m 9s
# ⏩ [517/14120] Skipped son012 — already processed
# 🔧 [518/14120] Processing: son013❌ [son013] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 26m 49s
# 🔧 [519/14120] Processing: son014✅ [son014] Torso detected — processing...
# ⚠️ [son014] Torso not detected after cleanup — skipping
#  ✓ done
#  ⏳ ETA: 30m 4s
# ⏩ [520/14120] Skipped son015 — already processed
# ⏩ [521/14120] Skipped son016 — already processed
# ⏩ [522/14120] Skipped son017 — already processed
# ⏩ [523/14120] Skipped son018 — already processed
# ⏩ [524/14120] Skipped son019 — already processed
# 🔧 [525/14120] Processing: son020❌ [son020] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 28m 45s
# ⏩ [526/14120] Skipped son021 — already processed
# 🔧 [527/14120] Processing: son022❌ [son022] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 27m 42s
# 🔧 [528/14120] Processing: son023❌ [son023] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 26m 35s
# ⏩ [529/14120] Skipped son024 — already processed
# 🔧 [530/14120] Processing: son025❌ [son025] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 25m 42s
# ⏩ [531/14120] Skipped son026 — already processed
# ⏩ [532/14120] Skipped son027 — already processed
# ⏩ [533/14120] Skipped son028 — already processed
# ⏩ [534/14120] Skipped son029 — already processed
# 🔧 [535/14120] Processing: dis065✅ [dis065] Torso detected — processing...
# ⚠️ [dis065] Torso not detected after cleanup — skipping
#  ✓ done
#  ⏳ ETA: 28m 21s
# ⏩ [536/14120] Skipped dis066 — already processed
# ⏩ [537/14120] Skipped dis067 — already processed
# ⏩ [538/14120] Skipped dis068 — already processed
# ⏩ [539/14120] Skipped dis069 — already processed
# ⏩ [540/14120] Skipped dis070 — already processed
# ⏩ [541/14120] Skipped dis071 — already processed
# ⏩ [542/14120] Skipped hfw001 — already processed
# 🔧 [543/14120] Processing: hfw002❌ [hfw002] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 27m 28s
# ⏩ [544/14120] Skipped hrz001 — already processed
# ⏩ [545/14120] Skipped hrz002 — already processed
# ⏩ [546/14120] Skipped avt001 — already processed
# ⏩ [547/14120] Skipped avt002 — already processed
# ⏩ [548/14120] Skipped avt003 — already processed
# ⏩ [549/14120] Skipped avt004 — already processed
# ⏩ [550/14120] Skipped avt005 — already processed
# ⏩ [551/14120] Skipped avt006 — already processed
# ⏩ [552/14120] Skipped avt007 — already processed
# ⏩ [553/14120] Skipped avt008 — already processed
# ⏩ [554/14120] Skipped avt009 — already processed
# ⏩ [555/14120] Skipped avt010 — already processed
# ⏩ [556/14120] Skipped avt011 — already processed
# ⏩ [557/14120] Skipped avt012 — already processed
# ⏩ [558/14120] Skipped avt013 — already processed
# ⏩ [559/14120] Skipped avt014 — already processed
# ⏩ [560/14120] Skipped avt015 — already processed
# ⏩ [561/14120] Skipped avt016 — already processed
# ⏩ [562/14120] Skipped avt017 — already processed
# ⏩ [563/14120] Skipped avt018 — already processed
# ⏩ [564/14120] Skipped avt019 — already processed
# ⏩ [565/14120] Skipped avt020 — already processed
# ⏩ [566/14120] Skipped avt021 — already processed
# ⏩ [567/14120] Skipped avt022 — already processed
# ⏩ [568/14120] Skipped avt023 — already processed
# ⏩ [569/14120] Skipped avt024 — already processed
# ⏩ [570/14120] Skipped avt025 — already processed
# ⏩ [571/14120] Skipped avt026 — already processed
# ⏩ [572/14120] Skipped avt027 — already processed
# ⏩ [573/14120] Skipped cty0505 — already processed
# ⏩ [574/14120] Skipped trn001 — already processed
# ⏩ [575/14120] Skipped trn002 — already processed
# ⏩ [576/14120] Skipped trn045 — already processed
# ⏩ [577/14120] Skipped trn046 — already processed
# ⏩ [578/14120] Skipped trn047 — already processed
# ⏩ [579/14120] Skipped trn048 — already processed
# ⏩ [580/14120] Skipped trn049 — already processed
# ⏩ [581/14120] Skipped trn050 — already processed
# ⏩ [582/14120] Skipped trn051 — already processed
# ⏩ [583/14120] Skipped trn052 — already processed
# ⏩ [584/14120] Skipped trn053 — already processed
# ⏩ [585/14120] Skipped trn054 — already processed
# ⏩ [586/14120] Skipped trn055 — already processed
# ⏩ [587/14120] Skipped trn056 — already processed
# ⏩ [588/14120] Skipped trn057 — already processed
# ⏩ [589/14120] Skipped trn058 — already processed
# ⏩ [590/14120] Skipped trn059 — already processed
# ⏩ [591/14120] Skipped trn060 — already processed
# ⏩ [592/14120] Skipped trn061 — already processed
# ⏩ [593/14120] Skipped trn062 — already processed
# ⏩ [594/14120] Skipped trn063 — already processed
# ⏩ [595/14120] Skipped trn064 — already processed
# ⏩ [596/14120] Skipped trn065 — already processed
# ⏩ [597/14120] Skipped trn067 — already processed
# ⏩ [598/14120] Skipped trn071 — already processed
# ⏩ [599/14120] Skipped trn072 — already processed
# ⏩ [600/14120] Skipped trn073 — already processed
# ⏩ [601/14120] Skipped trn075 — already processed
# ⏩ [602/14120] Skipped trn076 — already processed
# ⏩ [603/14120] Skipped trn080 — already processed
# ⏩ [604/14120] Skipped trn081 — already processed
# ⏩ [605/14120] Skipped trn082 — already processed
# ⏩ [606/14120] Skipped trn102 — already processed
# ⏩ [607/14120] Skipped trn102a — already processed
# ⏩ [608/14120] Skipped trn115 — already processed
# ⏩ [609/14120] Skipped trn115a — already processed
# ⏩ [610/14120] Skipped trn118 — already processed
# ⏩ [611/14120] Skipped trn120 — already processed
# ⏩ [612/14120] Skipped trn121 — already processed
# ⏩ [613/14120] Skipped trn122 — already processed
# ⏩ [614/14120] Skipped trn123 — already processed
# ⏩ [615/14120] Skipped trn128 — already processed
# ⏩ [616/14120] Skipped trn129a — already processed
# ⏩ [617/14120] Skipped trn130 — already processed
# ⏩ [618/14120] Skipped trn131 — already processed
# ⏩ [619/14120] Skipped trn132 — already processed
# ⏩ [620/14120] Skipped trn138 — already processed
# ⏩ [621/14120] Skipped trn143 — already processed
# ⏩ [622/14120] Skipped trn144 — already processed
# ⏩ [623/14120] Skipped trn145 — already processed
# ⏩ [624/14120] Skipped trn146 — already processed
# ⏩ [625/14120] Skipped trn147 — already processed
# ⏩ [626/14120] Skipped trn148 — already processed
# ⏩ [627/14120] Skipped trn149 — already processed
# ⏩ [628/14120] Skipped trn150 — already processed
# ⏩ [629/14120] Skipped trn151 — already processed
# ⏩ [630/14120] Skipped trn152 — already processed
# ⏩ [631/14120] Skipped trn222 — already processed
# ⏩ [632/14120] Skipped trn223 — already processed
# ⏩ [633/14120] Skipped trn224 — already processed
# ⏩ [634/14120] Skipped trn225 — already processed
# ⏩ [635/14120] Skipped trn226 — already processed
# ⏩ [636/14120] Skipped trn227 — already processed
# ⏩ [637/14120] Skipped trn227a — already processed
# ⏩ [638/14120] Skipped trn228 — already processed
# ⏩ [639/14120] Skipped trn229 — already processed
# ⏩ [640/14120] Skipped trn230 — already processed
# ⏩ [641/14120] Skipped trn231 — already processed
# ⏩ [642/14120] Skipped trn232 — already processed
# ⏩ [643/14120] Skipped trn233 — already processed
# ⏩ [644/14120] Skipped trn234 — already processed
# ⏩ [645/14120] Skipped trn235 — already processed
# ⏩ [646/14120] Skipped trn235a — already processed
# ⏩ [647/14120] Skipped trn236 — already processed
# ⏩ [648/14120] Skipped trn237 — already processed
# ⏩ [649/14120] Skipped trn238 — already processed
# ⏩ [650/14120] Skipped trn239 — already processed
# ⏩ [651/14120] Skipped trn240 — already processed
# ⏩ [652/14120] Skipped trn242 — already processed
# ⏩ [653/14120] Skipped trn243 — already processed
# ⏩ [654/14120] Skipped trn244 — already processed
# ⏩ [655/14120] Skipped trn245 — already processed
# ⏩ [656/14120] Skipped trn246 — already processed
# ⏩ [657/14120] Skipped trn252 — already processed
# ⏩ [658/14120] Skipped trn253 — already processed
# ⏩ [659/14120] Skipped trn254 — already processed
# ⏩ [660/14120] Skipped drm001 — already processed
# 🔧 [661/14120] Processing: drm002❌ [drm002] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 26m 19s
# ⏩ [662/14120] Skipped drm003 — already processed
# ⏩ [663/14120] Skipped drm004 — already processed
# 🔧 [664/14120] Processing: drm005❌ [drm005] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 25m 34s
# 🔧 [665/14120] Processing: drm006❌ [drm006] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 24m 45s
# ⏩ [666/14120] Skipped drm007 — already processed
# ⏩ [667/14120] Skipped drm008 — already processed
# ⏩ [668/14120] Skipped drm009 — already processed
# ⏩ [669/14120] Skipped drm010 — already processed
# 🔧 [670/14120] Processing: drm011❌ [drm011] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 24m 6s
# ⏩ [671/14120] Skipped drm012 — already processed
# 🔧 [672/14120] Processing: drm013❌ [drm013] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 23m 23s
# ⏩ [673/14120] Skipped drm014 — already processed
# ⏩ [674/14120] Skipped drm015 — already processed
# ⏩ [675/14120] Skipped drm016 — already processed
# 🔧 [676/14120] Processing: drm017❌ [drm017] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 22m 42s
# 🔧 [677/14120] Processing: drm018❌ [drm018] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 22m 4s
# 🔧 [678/14120] Processing: drm019❌ [drm019] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 21m 34s
# ⏩ [679/14120] Skipped drm020 — already processed
# ⏩ [680/14120] Skipped drm021 — already processed
# 🔧 [681/14120] Processing: drm022❌ [drm022] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 20m 59s
# 🔧 [682/14120] Processing: drm023❌ [drm023] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 20m 27s
# 🔧 [683/14120] Processing: drm024❌ [drm024] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 19m 56s
# 🔧 [684/14120] Processing: drm025❌ [drm025] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 19m 27s
# 🔧 [685/14120] Processing: drm026❌ [drm026] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 19m 0s
# ⏩ [686/14120] Skipped drm027 — already processed
# 🔧 [687/14120] Processing: drm028❌ [drm028] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 18m 34s
# ⏩ [688/14120] Skipped drm029 — already processed
# ⏩ [689/14120] Skipped drm030 — already processed
# ⏩ [690/14120] Skipped drm031 — already processed
# ⏩ [691/14120] Skipped drm032 — already processed
# 🔧 [692/14120] Processing: drm033✅ [drm033] Torso detected — processing...
# ⚠️ [drm033] Torso not detected after cleanup — skipping
#  ✓ done
#  ⏳ ETA: 20m 29s
# ⏩ [693/14120] Skipped drm034 — already processed
# ⏩ [694/14120] Skipped drm035 — already processed
# 🔧 [695/14120] Processing: drm036❌ [drm036] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 20m 3s
# 🔧 [696/14120] Processing: drm037❌ [drm037] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 19m 38s
# ⏩ [697/14120] Skipped drm038 — already processed
# ⏩ [698/14120] Skipped drm039 — already processed
# ⏩ [699/14120] Skipped drm040 — already processed
# ⏩ [700/14120] Skipped drm041 — already processed
# 🔧 [701/14120] Processing: drm042❌ [drm042] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 19m 17s
# 🔧 [702/14120] Processing: drm043❌ [drm043] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 18m 54s
# ⏩ [703/14120] Skipped drm044 — already processed
# ⏩ [704/14120] Skipped drm045 — already processed
# 🔧 [705/14120] Processing: drm046❌ [drm046] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 18m 32s
# ⏩ [706/14120] Skipped drm047 — already processed
# ⏩ [707/14120] Skipped drm048 — already processed
# ⏩ [708/14120] Skipped drm049 — already processed
# ⏩ [709/14120] Skipped drm050 — already processed
# ⏩ [710/14120] Skipped drm051 — already processed
# ⏩ [711/14120] Skipped drm052 — already processed
# ⏩ [712/14120] Skipped drm053 — already processed
# ⏩ [713/14120] Skipped drm054 — already processed
# 🔧 [714/14120] Processing: drm055✅ [drm055] Torso detected — processing...
# ⚠️ [drm055] Torso not detected after cleanup — skipping
#  ✓ done
#  ⏳ ETA: 20m 16s
# ⏩ [715/14120] Skipped drm056 — already processed
# ⏩ [716/14120] Skipped drm057 — already processed
# ⏩ [717/14120] Skipped drm058 — already processed
# ⏩ [718/14120] Skipped drm059 — already processed
# ⏩ [719/14120] Skipped drm060 — already processed
# ⏩ [720/14120] Skipped drm061 — already processed
# ⏩ [721/14120] Skipped drm062 — already processed
# 🔧 [722/14120] Processing: drm063❌ [drm063] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 19m 53s
# 🔧 [723/14120] Processing: drm064❌ [drm064] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 19m 31s
# 🔧 [724/14120] Processing: drm065❌ [drm065] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 19m 9s
# 🔧 [725/14120] Processing: drm066❌ [drm066] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 18m 48s
# ⏩ [726/14120] Skipped drm067 — already processed
# ⏩ [727/14120] Skipped drm068 — already processed
# ⏩ [728/14120] Skipped drm069 — already processed
# 🔧 [729/14120] Processing: drm070❌ [drm070] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 18m 28s
# ⏩ [730/14120] Skipped drm071 — already processed
# ⏩ [731/14120] Skipped drm072 — already processed
# 🔧 [732/14120] Processing: drm073s❌ [drm073s] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 18m 9s
# 🔧 [733/14120] Processing: drm074❌ [drm074] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 17m 51s
# ⏩ [734/14120] Skipped drm075 — already processed
# ⏩ [735/14120] Skipped drm076 — already processed
# ⏩ [736/14120] Skipped drm077 — already processed
# ⏩ [737/14120] Skipped drm078 — already processed
# 🔧 [738/14120] Processing: drm079❌ [drm079] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 17m 33s
# 🔧 [739/14120] Processing: drm080❌ [drm080] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 17m 19s
# 🔧 [740/14120] Processing: drm081❌ [drm081] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 17m 3s
# ⏩ [741/14120] Skipped drm082 — already processed
# ⏩ [742/14120] Skipped dun001 — already processed
# ⏩ [743/14120] Skipped dun002 — already processed
# ⏩ [744/14120] Skipped dun003 — already processed
# ⏩ [745/14120] Skipped dun004 — already processed
# ⏩ [746/14120] Skipped dun005 — already processed
# ⏩ [747/14120] Skipped dun006 — already processed
# ⏩ [748/14120] Skipped dun007 — already processed
# ⏩ [749/14120] Skipped dun008 — already processed
# ⏩ [750/14120] Skipped loz001 — already processed
# ⏩ [751/14120] Skipped loz002 — already processed
# ⏩ [752/14120] Skipped loz003 — already processed
# ⏩ [753/14120] Skipped loz004 — already processed
# ⏩ [754/14120] Skipped fort001 — already processed
# ⏩ [755/14120] Skipped fort002 — already processed
# ⏩ [756/14120] Skipped fort003 — already processed
# ⏩ [757/14120] Skipped fort004 — already processed
# ⏩ [758/14120] Skipped fort005 — already processed
# ⏩ [759/14120] Skipped fort006 — already processed
# ⏩ [760/14120] Skipped fort007 — already processed
# ⏩ [761/14120] Skipped fort008 — already processed
# ⏩ [762/14120] Skipped fort009 — already processed
# ⏩ [763/14120] Skipped gen005 — already processed
# ⏩ [764/14120] Skipped gen012 — already processed
# ⏩ [765/14120] Skipped tim001 — already processed
# ⏩ [766/14120] Skipped tim002 — already processed
# ⏩ [767/14120] Skipped tim003 — already processed
# ⏩ [768/14120] Skipped tim004 — already processed
# ⏩ [769/14120] Skipped tim005 — already processed
# ⏩ [770/14120] Skipped tim006 — already processed
# 🔧 [771/14120] Processing: tim007❌ [tim007] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 16m 44s
# ⏩ [772/14120] Skipped edu001 — already processed
# ⏩ [773/14120] Skipped edu002 — already processed
# ⏩ [774/14120] Skipped edu003 — already processed
# ⏩ [775/14120] Skipped edu004 — already processed
# ⏩ [776/14120] Skipped edu005 — already processed
# ⏩ [777/14120] Skipped edu006 — already processed
# ⏩ [778/14120] Skipped edu007 — already processed
# ⏩ [779/14120] Skipped edu008 — already processed
# ⏩ [780/14120] Skipped edu009 — already processed
# ⏩ [781/14120] Skipped edu010 — already processed
# ⏩ [782/14120] Skipped edu011 — already processed
# ⏩ [783/14120] Skipped edu012 — already processed
# ⏩ [784/14120] Skipped edu013 — already processed
# ⏩ [785/14120] Skipped edu014 — already processed
# ⏩ [786/14120] Skipped edu015 — already processed
# ⏩ [787/14120] Skipped edu016 — already processed
# ⏩ [788/14120] Skipped edu017 — already processed
# ⏩ [789/14120] Skipped edu018 — already processed
# ⏩ [790/14120] Skipped edu019 — already processed
# ⏩ [791/14120] Skipped edu020 — already processed
# ⏩ [792/14120] Skipped edu020a — already processed
# ⏩ [793/14120] Skipped edu020b — already processed
# ⏩ [794/14120] Skipped edu021 — already processed
# ⏩ [795/14120] Skipped edu021a — already processed
# ⏩ [796/14120] Skipped edu021b — already processed
# ⏩ [797/14120] Skipped edu022 — already processed
# ⏩ [798/14120] Skipped edu023 — already processed
# 🔧 [799/14120] Processing: gen036✅ [gen036] Torso detected — processing...
# ⚠️ [gen036] Torso not detected after cleanup — skipping
#  ✓ done
#  ⏳ ETA: 18m 21s
# 🔧 [800/14120] Processing: gen037✅ [gen037] Torso detected — processing...
# ⚠️ [gen037] Torso not detected after cleanup — skipping
#  ✓ done
#  ⏳ ETA: 19m 44s
# ⏩ [801/14120] Skipped pln191 — already processed
# ⏩ [802/14120] Skipped pln192 — already processed
# ⏩ [803/14120] Skipped pln193 — already processed
# ⏩ [804/14120] Skipped pln194 — already processed
# ⏩ [805/14120] Skipped pln197 — already processed
# ⏩ [806/14120] Skipped alp001 — already processed
# ⏩ [807/14120] Skipped alp002 — already processed
# ⏩ [808/14120] Skipped alp003 — already processed
# ⏩ [809/14120] Skipped alp004 — already processed
# ⏩ [810/14120] Skipped alp005 — already processed
# ⏩ [811/14120] Skipped alp006 — already processed
# 🔧 [812/14120] Processing: alp007❌ [alp007] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 19m 26s
# ⏩ [813/14120] Skipped alp008 — already processed
# ⏩ [814/14120] Skipped alp009 — already processed
# ⏩ [815/14120] Skipped alp010 — already processed
# ⏩ [816/14120] Skipped alp012 — already processed
# ⏩ [817/14120] Skipped alp015 — already processed
# ⏩ [818/14120] Skipped alp016 — already processed
# ⏩ [819/14120] Skipped alp017 — already processed
# ⏩ [820/14120] Skipped alp017a — already processed
# ⏩ [821/14120] Skipped alp018 — already processed
# ⏩ [822/14120] Skipped alp019 — already processed
# ⏩ [823/14120] Skipped alp020 — already processed
# ⏩ [824/14120] Skipped alp021 — already processed
# ⏩ [825/14120] Skipped alp022 — already processed
# ⏩ [826/14120] Skipped alp023 — already processed
# ⏩ [827/14120] Skipped alp024 — already processed
# ⏩ [828/14120] Skipped alp025 — already processed
# ⏩ [829/14120] Skipped alp026 — already processed
# ⏩ [830/14120] Skipped alp027 — already processed
# ⏩ [831/14120] Skipped alp028 — already processed
# ⏩ [832/14120] Skipped alp029 — already processed
# ⏩ [833/14120] Skipped alp030 — already processed
# ⏩ [834/14120] Skipped alp031 — already processed
# ⏩ [835/14120] Skipped alp032 — already processed
# ⏩ [836/14120] Skipped alp033 — already processed
# ⏩ [837/14120] Skipped alp034 — already processed
# ⏩ [838/14120] Skipped cc4058 — already processed
# ⏩ [839/14120] Skipped cc4061 — already processed
# ⏩ [840/14120] Skipped cc4063 — already processed
# ⏩ [841/14120] Skipped cc4064 — already processed
# ⏩ [842/14120] Skipped cc4065 — already processed
# ⏩ [843/14120] Skipped cc4066 — already processed
# ⏩ [844/14120] Skipped gen003 — already processed
# ⏩ [845/14120] Skipped hrf001 — already processed
# ⏩ [846/14120] Skipped hrf002 — already processed
# ⏩ [847/14120] Skipped hrf003 — already processed
# ⏩ [848/14120] Skipped hrf004 — already processed
# ⏩ [849/14120] Skipped hrf004new — already processed
# ⏩ [850/14120] Skipped hrf005 — already processed
# ⏩ [851/14120] Skipped hrf006 — already processed
# ⏩ [852/14120] Skipped hrf007 — already processed
# ⏩ [853/14120] Skipped hrf008 — already processed
# ⏩ [854/14120] Skipped hrf009 — already processed
# ⏩ [855/14120] Skipped hrf010 — already processed
# ⏩ [856/14120] Skipped hrf011 — already processed
# ⏩ [857/14120] Skipped hrf012 — already processed
# ⏩ [858/14120] Skipped stu001 — already processed
# ⏩ [859/14120] Skipped stu002 — already processed
# ⏩ [860/14120] Skipped stu003 — already processed
# ⏩ [861/14120] Skipped stu005 — already processed
# ⏩ [862/14120] Skipped stu006 — already processed
# ⏩ [863/14120] Skipped stu008 — already processed
# ⏩ [864/14120] Skipped stu009 — already processed
# ⏩ [865/14120] Skipped stu010 — already processed
# ⏩ [866/14120] Skipped stu010a — already processed
# ⏩ [867/14120] Skipped stu010b — already processed
# ⏩ [868/14120] Skipped stu011 — already processed
# ⏩ [869/14120] Skipped stu012 — already processed
# ⏩ [870/14120] Skipped stu013a — already processed
# ⏩ [871/14120] Skipped stu014 — already processed
# ⏩ [872/14120] Skipped stu015 — already processed
# ⏩ [873/14120] Skipped stu016 — already processed
# ⏩ [874/14120] Skipped wc4060 — already processed
# 🔧 [875/14120] Processing: 30598pb01❌ [30598pb01] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 19m 4s
# 🔧 [876/14120] Processing: 30598pb02❌ [30598pb02] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 18m 47s
# 🔧 [877/14120] Processing: 30598pb03❌ [30598pb03] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 18m 31s
# 🔧 [878/14120] Processing: 30598pb04❌ [30598pb04] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 18m 16s
# 🔧 [879/14120] Processing: 30598pb05❌ [30598pb05] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 18m 1s
# 🔧 [880/14120] Processing: 30598pb06❌ [30598pb06] No torso detected — skipping
#  → saved to ignored_minifigures
#  ⏳ ETA: 17m 46s
# ...
#  ✓ done
#  ⏳ ETA: 0m 24s
# 🔧 [13996/14120] Processing: tls033✅ [tls033] Torso detected — processing...
# 💾 [tls033] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 24s
# 🔧 [13997/14120] Processing: tls034✅ [tls034] Torso detected — processing...
# 💾 [tls034] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 24s
# 🔧 [13998/14120] Processing: tls035✅ [tls035] Torso detected — processing...
# 💾 [tls035] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 24s
# 🔧 [13999/14120] Processing: tls036✅ [tls036] Torso detected — processing...
# 💾 [tls036] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 24s
# 🔧 [14000/14120] Processing: tls037✅ [tls037] Torso detected — processing...
# 💾 [tls037] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 23s
# 🔧 [14001/14120] Processing: tls038✅ [tls038] Torso detected — processing...
# 💾 [tls038] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 23s
# 🔧 [14002/14120] Processing: tls039✅ [tls039] Torso detected — processing...
# 💾 [tls039] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 23s
# 🔧 [14003/14120] Processing: tls040✅ [tls040] Torso detected — processing...
# 💾 [tls040] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 23s
# 🔧 [14004/14120] Processing: tls041✅ [tls041] Torso detected — processing...
# 💾 [tls041] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 23s
# 🔧 [14005/14120] Processing: tls042✅ [tls042] Torso detected — processing...
# 💾 [tls042] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 23s
# 🔧 [14006/14120] Processing: tls043✅ [tls043] Torso detected — processing...
# 💾 [tls043] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 22s
# 🔧 [14007/14120] Processing: tls044✅ [tls044] Torso detected — processing...
# 💾 [tls044] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 22s
# 🔧 [14008/14120] Processing: tls045✅ [tls045] Torso detected — processing...
# 💾 [tls045] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 22s
# 🔧 [14009/14120] Processing: tls046✅ [tls046] Torso detected — processing...
# 💾 [tls046] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 22s
# 🔧 [14010/14120] Processing: tls047✅ [tls047] Torso detected — processing...
# 💾 [tls047] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 22s
# 🔧 [14011/14120] Processing: tls048✅ [tls048] Torso detected — processing...
# 💾 [tls048] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 22s
# 🔧 [14012/14120] Processing: tls049✅ [tls049] Torso detected — processing...
# 💾 [tls049] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 21s
# 🔧 [14013/14120] Processing: tls050✅ [tls050] Torso detected — processing...
# 💾 [tls050] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 21s
# 🔧 [14014/14120] Processing: tls051✅ [tls051] Torso detected — processing...
# 💾 [tls051] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 21s
# 🔧 [14015/14120] Processing: tls052✅ [tls052] Torso detected — processing...
# 💾 [tls052] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 21s
# 🔧 [14016/14120] Processing: tls053✅ [tls053] Torso detected — processing...
# 💾 [tls053] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 21s
# 🔧 [14017/14120] Processing: tls054✅ [tls054] Torso detected — processing...
# 💾 [tls054] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 20s
# 🔧 [14018/14120] Processing: tls055✅ [tls055] Torso detected — processing...
# 💾 [tls055] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 20s
# 🔧 [14019/14120] Processing: tls056✅ [tls056] Torso detected — processing...
# 💾 [tls056] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 20s
# 🔧 [14020/14120] Processing: tls057✅ [tls057] Torso detected — processing...
# 💾 [tls057] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 20s
# 🔧 [14021/14120] Processing: tls058✅ [tls058] Torso detected — processing...
# 💾 [tls058] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 20s
# 🔧 [14022/14120] Processing: tls059✅ [tls059] Torso detected — processing...
# 💾 [tls059] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 20s
# 🔧 [14023/14120] Processing: tls060✅ [tls060] Torso detected — processing...
# 💾 [tls060] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 19s
# 🔧 [14024/14120] Processing: tls061✅ [tls061] Torso detected — processing...
# 💾 [tls061] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 19s
# 🔧 [14025/14120] Processing: tls062✅ [tls062] Torso detected — processing...
# 💾 [tls062] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 19s
# 🔧 [14026/14120] Processing: tls063✅ [tls063] Torso detected — processing...
# 💾 [tls063] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 19s
# 🔧 [14027/14120] Processing: tls064✅ [tls064] Torso detected — processing...
# 💾 [tls064] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 19s
# 🔧 [14028/14120] Processing: tls065✅ [tls065] Torso detected — processing...
# 💾 [tls065] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 18s
# 🔧 [14029/14120] Processing: tls066✅ [tls066] Torso detected — processing...
# 💾 [tls066] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 18s
# 🔧 [14030/14120] Processing: tls067✅ [tls067] Torso detected — processing...
# 💾 [tls067] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 18s
# 🔧 [14031/14120] Processing: tls068✅ [tls068] Torso detected — processing...
# 💾 [tls068] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 18s
# 🔧 [14032/14120] Processing: tls069✅ [tls069] Torso detected — processing...
# 💾 [tls069] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 18s
# 🔧 [14033/14120] Processing: tls070✅ [tls070] Torso detected — processing...
# 💾 [tls070] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 17s
# 🔧 [14034/14120] Processing: tls071✅ [tls071] Torso detected — processing...
# 💾 [tls071] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 17s
# 🔧 [14035/14120] Processing: tls072✅ [tls072] Torso detected — processing...
# 💾 [tls072] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 17s
# 🔧 [14036/14120] Processing: tls073✅ [tls073] Torso detected — processing...
# 💾 [tls073] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 17s
# 🔧 [14037/14120] Processing: tls074✅ [tls074] Torso detected — processing...
# 💾 [tls074] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 17s
# 🔧 [14038/14120] Processing: tls075✅ [tls075] Torso detected — processing...
# 💾 [tls075] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 17s
# 🔧 [14039/14120] Processing: tls076✅ [tls076] Torso detected — processing...
# 💾 [tls076] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 16s
# 🔧 [14040/14120] Processing: tls077✅ [tls077] Torso detected — processing...
# 💾 [tls077] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 16s
# 🔧 [14041/14120] Processing: tls078✅ [tls078] Torso detected — processing...
# 💾 [tls078] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 16s
# 🔧 [14042/14120] Processing: tls079✅ [tls079] Torso detected — processing...
# 💾 [tls079] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 16s
# 🔧 [14043/14120] Processing: tls080✅ [tls080] Torso detected — processing...
# 💾 [tls080] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 16s
# 🔧 [14044/14120] Processing: tls081✅ [tls081] Torso detected — processing...
# 💾 [tls081] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 15s
# 🔧 [14045/14120] Processing: tls082✅ [tls082] Torso detected — processing...
# 💾 [tls082] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 15s
# 🔧 [14046/14120] Processing: tls083✅ [tls083] Torso detected — processing...
# 💾 [tls083] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 15s
# 🔧 [14047/14120] Processing: tls084✅ [tls084] Torso detected — processing...
# 💾 [tls084] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 15s
# 🔧 [14048/14120] Processing: tls085✅ [tls085] Torso detected — processing...
# 💾 [tls085] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 15s
# 🔧 [14049/14120] Processing: tls086✅ [tls086] Torso detected — processing...
# 💾 [tls086] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 14s
# 🔧 [14050/14120] Processing: tls087✅ [tls087] Torso detected — processing...
# 💾 [tls087] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 14s
# 🔧 [14051/14120] Processing: tls088✅ [tls088] Torso detected — processing...
# 💾 [tls088] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 14s
# 🔧 [14052/14120] Processing: tls088a✅ [tls088a] Torso detected — processing...
# 💾 [tls088a] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 14s
# 🔧 [14053/14120] Processing: tls089✅ [tls089] Torso detected — processing...
# 💾 [tls089] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 14s
# 🔧 [14054/14120] Processing: tls090✅ [tls090] Torso detected — processing...
# 💾 [tls090] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 13s
# 🔧 [14055/14120] Processing: tls091✅ [tls091] Torso detected — processing...
# 💾 [tls091] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 13s
# 🔧 [14056/14120] Processing: tls092✅ [tls092] Torso detected — processing...
# 💾 [tls092] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 13s
# 🔧 [14057/14120] Processing: tls093✅ [tls093] Torso detected — processing...
# 💾 [tls093] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 13s
# 🔧 [14058/14120] Processing: tls094✅ [tls094] Torso detected — processing...
# 💾 [tls094] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 13s
# 🔧 [14059/14120] Processing: tls095✅ [tls095] Torso detected — processing...
# 💾 [tls095] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 12s
# 🔧 [14060/14120] Processing: tls096✅ [tls096] Torso detected — processing...
# 💾 [tls096] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 12s
# 🔧 [14061/14120] Processing: tls097✅ [tls097] Torso detected — processing...
# 💾 [tls097] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 12s
# 🔧 [14062/14120] Processing: tls098✅ [tls098] Torso detected — processing...
# 💾 [tls098] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 12s
# 🔧 [14063/14120] Processing: tls099✅ [tls099] Torso detected — processing...
# 💾 [tls099] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 12s
# 🔧 [14064/14120] Processing: tls100✅ [tls100] Torso detected — processing...
# 💾 [tls100] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 11s
# 🔧 [14065/14120] Processing: tls101✅ [tls101] Torso detected — processing...
# 💾 [tls101] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 11s
# 🔧 [14066/14120] Processing: tls102✅ [tls102] Torso detected — processing...
# 💾 [tls102] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 11s
# 🔧 [14067/14120] Processing: tls103✅ [tls103] Torso detected — processing...
# 💾 [tls103] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 11s
# 🔧 [14068/14120] Processing: tls104✅ [tls104] Torso detected — processing...
# 💾 [tls104] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 11s
# 🔧 [14069/14120] Processing: tls105✅ [tls105] Torso detected — processing...
# 💾 [tls105] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 10s
# 🔧 [14070/14120] Processing: tls106✅ [tls106] Torso detected — processing...
# 💾 [tls106] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 10s
# 🔧 [14071/14120] Processing: tls107✅ [tls107] Torso detected — processing...
# 💾 [tls107] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 10s
# 🔧 [14072/14120] Processing: tls108✅ [tls108] Torso detected — processing...
# 💾 [tls108] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 10s
# 🔧 [14073/14120] Processing: tls109✅ [tls109] Torso detected — processing...
# 💾 [tls109] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 10s
# 🔧 [14074/14120] Processing: tls110✅ [tls110] Torso detected — processing...
# 💾 [tls110] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 9s
# 🔧 [14075/14120] Processing: tls111✅ [tls111] Torso detected — processing...
# 💾 [tls111] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 9s
# 🔧 [14076/14120] Processing: tls112✅ [tls112] Torso detected — processing...
# 💾 [tls112] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 9s
# 🔧 [14077/14120] Processing: tls113✅ [tls113] Torso detected — processing...
# 💾 [tls113] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 9s
# 🔧 [14078/14120] Processing: tls114✅ [tls114] Torso detected — processing...
# 💾 [tls114] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 9s
# 🔧 [14079/14120] Processing: tls115✅ [tls115] Torso detected — processing...
# 💾 [tls115] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 8s
# 🔧 [14080/14120] Processing: tls116✅ [tls116] Torso detected — processing...
# 💾 [tls116] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 8s
# 🔧 [14081/14120] Processing: tls117✅ [tls117] Torso detected — processing...
# 💾 [tls117] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 8s
# 🔧 [14082/14120] Processing: tls118✅ [tls118] Torso detected — processing...
# 💾 [tls118] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 8s
# 🔧 [14083/14120] Processing: tls119✅ [tls119] Torso detected — processing...
# 💾 [tls119] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 7s
# 🔧 [14084/14120] Processing: tls120✅ [tls120] Torso detected — processing...
# 💾 [tls120] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 7s
# 🔧 [14085/14120] Processing: tls121✅ [tls121] Torso detected — processing...
# 💾 [tls121] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 7s
# 🔧 [14086/14120] Processing: tls122✅ [tls122] Torso detected — processing...
# 💾 [tls122] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 7s
# 🔧 [14087/14120] Processing: tls123✅ [tls123] Torso detected — processing...
# 💾 [tls123] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 7s
# 🔧 [14088/14120] Processing: tls124✅ [tls124] Torso detected — processing...
# 💾 [tls124] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 6s
# 🔧 [14089/14120] Processing: twn348✅ [twn348] Torso detected — processing...
# 💾 [twn348] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 6s
# 🔧 [14090/14120] Processing: twn349✅ [twn349] Torso detected — processing...
# 💾 [twn349] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 6s
# 🔧 [14091/14120] Processing: twn350✅ [twn350] Torso detected — processing...
# 💾 [twn350] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 6s
# 🔧 [14092/14120] Processing: twn351✅ [twn351] Torso detected — processing...
# 💾 [twn351] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 6s
# 🔧 [14093/14120] Processing: twn352✅ [twn352] Torso detected — processing...
# 💾 [twn352] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 5s
# 🔧 [14094/14120] Processing: twn353✅ [twn353] Torso detected — processing...
# 💾 [twn353] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 5s
# 🔧 [14095/14120] Processing: twn354✅ [twn354] Torso detected — processing...
# 💾 [twn354] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 5s
# 🔧 [14096/14120] Processing: twn355✅ [twn355] Torso detected — processing...
# 💾 [twn355] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 5s
# 🔧 [14097/14120] Processing: gen015✅ [gen015] Torso detected — processing...
# 💾 [gen015] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 5s
# 🔧 [14098/14120] Processing: gen041✅ [gen041] Torso detected — processing...
# 💾 [gen041] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 4s
# 🔧 [14099/14120] Processing: gen085✅ [gen085] Torso detected — processing...
# 💾 [gen085] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 4s
# 🔧 [14100/14120] Processing: gen086✅ [gen086] Torso detected — processing...
# 💾 [gen086] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 4s
# 🔧 [14101/14120] Processing: gen087✅ [gen087] Torso detected — processing...
# 💾 [gen087] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 4s
# 🔧 [14102/14120] Processing: gen097✅ [gen097] Torso detected — processing...
# 💾 [gen097] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 3s
# 🔧 [14103/14120] Processing: gen140✅ [gen140] Torso detected — processing...
# 💾 [gen140] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 3s
# 🔧 [14104/14120] Processing: gen150✅ [gen150] Torso detected — processing...
# 💾 [gen150] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 3s
# 🔧 [14105/14120] Processing: gen153✅ [gen153] Torso detected — processing...
# 💾 [gen153] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 3s
# 🔧 [14106/14120] Processing: gen154✅ [gen154] Torso detected — processing...
# 💾 [gen154] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 3s
# 🔧 [14107/14120] Processing: gen157✅ [gen157] Torso detected — processing...
# 💾 [gen157] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 2s
# 🔧 [14108/14120] Processing: gen158✅ [gen158] Torso detected — processing...
# 💾 [gen158] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 2s
# 🔧 [14109/14120] Processing: gen161✅ [gen161] Torso detected — processing...
# 💾 [gen161] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 2s
# 🔧 [14110/14120] Processing: gen167✅ [gen167] Torso detected — processing...
# 💾 [gen167] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 2s
# 🔧 [14111/14120] Processing: gen168✅ [gen168] Torso detected — processing...
# 💾 [gen168] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 1s
# 🔧 [14112/14120] Processing: gen169✅ [gen169] Torso detected — processing...
# 💾 [gen169] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 1s
# 🔧 [14113/14120] Processing: gen170✅ [gen170] Torso detected — processing...
# 💾 [gen170] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 1s
# 🔧 [14114/14120] Processing: gen171✅ [gen171] Torso detected — processing...
# 💾 [gen171] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 1s
# 🔧 [14115/14120] Processing: gen183✅ [gen183] Torso detected — processing...
# 💾 [gen183] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 1s
# 🔧 [14116/14120] Processing: gen187✅ [gen187] Torso detected — processing...
# 💾 [gen187] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 0s
# 🔧 [14117/14120] Processing: gen188✅ [gen188] Torso detected — processing...
# 💾 [gen188] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 0s
# 🔧 [14118/14120] Processing: gen189✅ [gen189] Torso detected — processing...
# 💾 [gen189] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 0s
# 🔧 [14119/14120] Processing: gen190✅ [gen190] Torso detected — processing...
# 💾 [gen190] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 0s
# 🔧 [14120/14120] Processing: gen191✅ [gen191] Torso detected — processing...
# 💾 [gen191] Saved to data_set
#  ✓ done
#  ⏳ ETA: 0m 0s

# %% [markdown]
# # 7. Files are processed. Next step is embedding
